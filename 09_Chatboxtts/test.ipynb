# %%
from datasets import load_dataset, load_from_disk
dataset = load_from_disk("/media/bodza/Audio_Dataset/chatterbox_tts_dataset")
dataset
# Out:
# Dataset({
#     features: ['text', 'speech_tokens', 'speech_token_lens', 'speaker_embed', 'text_tokens', 'text_tokens_len'],
#     num_rows: 1000
# })
